# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#dataset before dropping NA values
df = pd.read_csv("kickstarter.csv")
df
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# ...

# %%
def load_and_process(url_or_path_to_csv_file):
    df1 = (
        pd.read_csv(url_or_path_to_csv_file)
        .dropna()
        .reset_index(drop=True)
    )
    df2 = (
        df1
        .assign(Percent_Funded= lambda x: x['pledged']/x['goal']*100)
        .reset_index(drop=True)
    )
    return df2

df = load_and_process("kickstarter.csv")

# %%
#Dataset after removing 
df
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 374855   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 374856   999977640                                          The Tribe
# 374857   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 374858   999987933                           BioDefense Education Kit
# 374859   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# ...

# %%
#Categories with the highest Mean Percent Funded listed in descending order
df2 = (
    df.loc[:,['main_category', 'Percent_Funded']]
    .groupby(by="main_category").mean()
    .sort_values('Percent_Funded', ascending=False)
    )
df2
# Out:
#                Percent_Funded
# main_category
# Music              817.961881
# Games              746.502457
# Comics             643.382447
# Technology         295.651588
# Art                249.235927
# Crafts             244.074641
# Design             208.084678
# Publishing         184.623887
# Film & Video       152.530698
# Theater            100.901195
# Fashion            100.408656
# Food                83.894856
# Dance               80.740848
# Photography         61.421045
# Journalism          50.108692

# %%
plt.figure(figsize=(25,10))
df2 = df[['main_category', 'Percent_Funded']]
sns.barplot(x = 'main_category', y='Percent_Funded', data=df2)
# Out:
# <AxesSubplot:xlabel='main_category', ylabel='Percent_Funded'>

# %%
# List of all failed projects
df3 = df[['name', 'main_category', 'goal', 'pledged', 'state', "Percent_Funded"]]
df3 = df3.loc[df3['state']=='failed'].sort_values('goal', ascending=False).reset_index(drop=True)
df3
# Out:
#                                                      name main_category  \
# 0                                                   Peace  Film & Video
# 1       DER NEANDERTALER (Kinofilm mit Starbesetzung i...  Film & Video
# 2                                         Art Is Fabulous           Art
# 3                                     A Billion Pixels...    Technology
# 4                                   Is Anyone Out There ?    Technology
# ...                                                   ...           ...
# 197606                              Springfield Hemp Fest           Art
# 197607                                        SugarSmarts    Technology
# 197608                                         Solar Bike    Technology
# 197609                           RocknRoll NoisePollution  Film & Video
# 197610                                               Nana  Film & Video
#
#                 goal  pledged   state  Percent_Funded
# ...

# %%
#List of failed projects, grouped by main_category, sorted by Percent_Funded in ascending order 
df4 = (
    df3.loc[:,['main_category', 'Percent_Funded']]
    .groupby(by="main_category").mean()
    .sort_values('Percent_Funded', ascending=True)
    )
df4
# Out:
#                Percent_Funded
# main_category
# Journalism           4.969719
# Technology           6.999254
# Food                 7.314633
# Crafts               8.053529
# Film & Video         8.167742
# Publishing           8.202469
# Fashion              8.488062
# Photography          8.649105
# Music                8.838973
# Art                  9.939940
# Dance               10.514125
# Theater             10.812849
# Games               11.974389
# Design              13.323667
# Comics              14.904474

# %%
# Film & Video is the most common category amongst failed projects
df3['main_category'].describe()
# Out:
# count           197611
# unique              15
# top       Film & Video
# freq             32891
# Name: main_category, dtype: object

# %%
#barplot of failed projects
plt.figure(figsize=(25,10))
sns.barplot(x=df3["main_category"], y=df3["Percent_Funded"])
# Out:
# <AxesSubplot:xlabel='main_category', ylabel='Percent_Funded'>
