# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

path= ("/Users/davidpinosproano/Desktop/COSC 301/project301/git/course-project-group_6004/analysis/kickstarter.csv")

def load_and_process(url_or_path_to_csv_file):
    df1 = pd.read_csv(url_or_path_to_csv_file).dropna()
    return df1

df = load_and_process(path)
df
# Out:
#                 ID                                               name  \
# 0       1000002330                    The Songs of Adelaide & Abullah
# 1       1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2       1000004038                                     Where is Hank?
# 3       1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4       1000011046  Community Film Project: The Art of Neighborhoo...
# ...            ...                                                ...
# 378656   999976400  ChknTruk Nationwide Charity Drive 2014 (Canceled)
# 378657   999977640                                          The Tribe
# 378658   999986353  Walls of Remedy- New lesbian Romantic Comedy f...
# 378659   999987933                           BioDefense Education Kit
# 378660   999988282                  Nou Renmen Ayiti!  We Love Haiti!
#
#                category main_category currency    deadline     goal  \
# 0                Poetry    Publishing      GBP  2015-10-09   1000.0
# 1        Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2        Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3                 Music         Music      USD  2012-04-16   5000.0
# 4          Film & Video  Film & Video      USD  2015-08-29  19500.0
# ...                 ...           ...      ...         ...      ...
# 378656      Documentary  Film & Video      USD  2014-10-17  50000.0
# 378657   Narrative Film  Film & Video      USD  2011-07-19   1500.0
# 378658   Narrative Film  Film & Video      USD  2010-08-16  15000.0
# 378659       Technology    Technology      USD  2016-02-13  15000.0
# 378660  Performance Art           Art      USD  2011-08-16   2000.0
#
#                 launched  pledged     state  backers country  usd pledged  \
# 0       2015-08-11 12:12      0.0    failed        0      GB          0.0
# 1        2017-09-02 4:43   2421.0    failed       15      US        100.0
# 2        2013-01-12 0:20    220.0    failed        3      US        220.0
# 3        2012-03-17 3:24      1.0    failed        1      US          1.0
# 4        2015-07-04 8:35   1283.0  canceled       14      US       1283.0
# ...                  ...      ...       ...      ...     ...          ...
# 378656   2014-09-17 2:35     25.0  canceled        1      US         25.0
# 378657   2011-06-22 3:35    155.0    failed        5      US        155.0
# 378658  2010-07-01 19:40     20.0    failed        1      US         20.0
# 378659  2016-01-13 18:13    200.0    failed        6      US        200.0
# 378660   2011-07-19 9:07    524.0    failed       17      US        524.0
#
#         usd_pledged_real  usd_goal_real
# 0                    0.0        1533.95
# 1                 2421.0       30000.00
# 2                  220.0       45000.00
# 3                    1.0        5000.00
# 4                 1283.0       19500.00
# ...                  ...            ...
# 378656              25.0       50000.00
# 378657             155.0        1500.00
# 378658              20.0       15000.00
# 378659             200.0       15000.00
# 378660             524.0        2000.00
#
# [374860 rows x 15 columns]

# %%
sns.set_style("ticks")
sns.set_context("paper",font_scale=1.5)
# creating column that shows succes rate

df = df.assign(Percent_Funded= lambda df:df['pledged']/df['goal']*100)

df2 = df.loc[:,['main_category','Percent_Funded']]

df2 = df2.groupby(by="main_category").mean().sort_values('Percent_Funded',ascending =False)
df2 
# this is the percent funding per category
# Out:
#                Percent_Funded
# main_category
# Music              817.961881
# Games              746.502457
# Comics             643.382447
# Technology         295.651588
# Art                249.235927
# Crafts             244.074641
# Design             208.084678
# Publishing         184.623887
# Film & Video       152.530698
# Theater            100.901195
# Fashion            100.408656
# Food                83.894856
# Dance               80.740848
# Photography         61.421045
# Journalism          50.108692

# %%
# 100 biggest kickstarters campaigns that where sucessfully funded.
df3 = df[['name','main_category','goal','state']]
df3= df3.loc[df3['state']=='successful'].sort_values('goal',ascending =False).head(100).reset_index(drop=True)
df3
# Out:
#                                                  name main_category  \
# 0                     The Veronica Mars Movie Project  Film & Video
# 1             Bring Back MYSTERY SCIENCE THEATER 3000  Film & Video
# 2                                   Camelot Unchained         Games
# 3                                     WISH I WAS HERE  Film & Video
# 4                                           Shenmue 3         Games
# ..                                                ...           ...
# 95           Skriware - Home 3D Printing for everyone    Technology
# 96              Pakayak - The Ultimate Packable Kayak        Design
# 97                              JourneyQuest Season 3  Film & Video
# 98  "The Goon" Movie... let's KICKSTART this sucke...  Film & Video
# 99                Toejam and Earl: Back in the Groove         Games
#
#          goal       state
# 0   2000000.0  successful
# 1   2000000.0  successful
# 2   2000000.0  successful
# 3   2000000.0  successful
# 4   2000000.0  successful
# ..        ...         ...
# 95   440000.0  successful
# 96   427325.0  successful
# 97   420000.0  successful
# 98   400000.0  successful
# 99   400000.0  successful
#
# [100 rows x 4 columns]

# %%
# the top category within the 100 best startups was games appearing 43 times.Furthermore, there were 8 
#different cateogries within the top 100 

df3['main_category'].describe()
# Out:
# count       100
# unique        8
# top       Games
# freq         43
# Name: main_category, dtype: object

# %%
#  average number of backers per category 

df4 = df[['main_category','backers']]
df4 =df4.sort_values('backers',ascending = False)
plt.figure(figsize=(20, 10))
sns.barplot(x = "main_category" ,y='backers',data = df4)

# %%
df5 = df[['name','main_category','goal','state']]
df5= df5.loc[df5['state']=='successful'].sort_values('goal',ascending =False).reset_index(drop=True)

df5
# Out:
#                                             name main_category        goal  \
# 0                The Veronica Mars Movie Project  Film & Video  2000000.00
# 1        Bring Back MYSTERY SCIENCE THEATER 3000  Film & Video  2000000.00
# 2                              Camelot Unchained         Games  2000000.00
# 3                                WISH I WAS HERE  Film & Video  2000000.00
# 4                                      Shenmue 3         Games  2000000.00
# ...                                          ...           ...         ...
# 133846                              Chiefstarter           Art        1.00
# 133847  The fB Project - Mylife Yourlife Ourlife           Art        1.00
# 133848      Dark Thunder: The Desktop Wallpaper!        Comics        1.00
# 133849                       LENDEMAIN DE VEILLE         Music        1.00
# 133850   LOVELAND Round 6: A Force More Powerful           Art        0.01
#
#              state
# 0       successful
# 1       successful
# 2       successful
# 3       successful
# 4       successful
# ...            ...
# 133846  successful
# 133847  successful
# 133848  successful
# 133849  successful
# 133850  successful
#
# [133851 rows x 4 columns]

# %%
df5['main_category'].describe()
# music is the number one category that has the most sucessful startups
# Out:
# count     133851
# unique        15
# top        Music
# freq       24105
# Name: main_category, dtype: object

# %%
df5 = df5.sort_values('main_category',ascending =True)
plt.figure(figsize=(20, 10))

sns.displot(df5, x="main_category",height=10,aspect=2)

# %%
# Out:
#                                             name main_category        goal  \
# 0                The Veronica Mars Movie Project  Film & Video  2000000.00
# 1        Bring Back MYSTERY SCIENCE THEATER 3000  Film & Video  2000000.00
# 2                              Camelot Unchained         Games  2000000.00
# 3                                WISH I WAS HERE  Film & Video  2000000.00
# 4                                      Shenmue 3         Games  2000000.00
# ...                                          ...           ...         ...
# 133846                              Chiefstarter           Art        1.00
# 133847  The fB Project - Mylife Yourlife Ourlife           Art        1.00
# 133848      Dark Thunder: The Desktop Wallpaper!        Comics        1.00
# 133849                       LENDEMAIN DE VEILLE         Music        1.00
# 133850   LOVELAND Round 6: A Force More Powerful           Art        0.01
#
#              state
# 0       successful
# 1       successful
# 2       successful
# 3       successful
# 4       successful
# ...            ...
# 133846  successful
# 133847  successful
# 133848  successful
# 133849  successful
# 133850  successful
#
# [133851 rows x 4 columns]

# %%
#  count for every state for individual categories
sns.displot(df, x="main_category", hue="state",aspect =3,height =8)
